# %%
import joblib
import pandas as pd
import csv
import numpy as np
from itertools import zip_longest
import torch
from pathlib import Path
from tqdm import tqdm
from typing import Any, Dict, List, Optional, Tuple, Union
pd.set_option('display.max_rows', 200)

# %%
experiment_path = "../speech_hypertuning/experiments/create_splits/random/"
state = joblib.load(experiment_path + '/state.pkl')
df = state['dataset_metadata']

# %%
# Sort by audio count intercalated by gender
sid_to_audios_count = df.groupby(['speaker_id']).size().to_dict()
sid_to_gender = (
    df[['speaker_id', 'Gender']]
    .drop_duplicates()
    .set_index("speaker_id")
    .to_dict()["Gender"]
)
sorted_sid_by_audios_count = [
    sid
    for sid, _ in sorted(
        sid_to_audios_count.items(), key=lambda tuple: tuple[1], reverse=True
    )
]

sorted_male_sid_by_audios_count = [
    sid for sid in sorted_sid_by_audios_count if sid_to_gender[sid] == "m"
]
sorted_female_sid_by_audios_count = [
    sid for sid in sorted_sid_by_audios_count if sid_to_gender[sid] == "f"
]

alternated_list = []
for male_sid, female_sid in zip_longest(
    sorted_male_sid_by_audios_count, sorted_female_sid_by_audios_count
):
    if male_sid is not None:
        alternated_list.append(male_sid)
    if female_sid is not None:
        alternated_list.append(female_sid)

# %% [markdown]
# ## Naive

# %%
def process_sample_sizes(
    proportions: Dict[str, Union[int, float]],
    speaker_df: pd.DataFrame,
) -> Dict[str, int]:
    sample_sizes = {}
    for partition, v in proportions.items():
        if isinstance(v, float):
            sample_size = int(len(speaker_df) * v)
        elif isinstance(v, int):
            sample_size = int(v)
        else:
            raise ValueError(f"Unsoported value in proportions for partition {partition}: {v}")
        sample_sizes[partition] = sample_size
    return sample_sizes

def sort_idx_alternating_video_ids(
    speaker_df: pd.DataFrame,
    sampled_idxs: np.ndarray,
    sample_size: int,
) -> List[int]:
    """
    Sort indexes alternating one from each video id
    The reason of this is to take rows in order when subsampling,
    as having different videos is more valuable than multiple
    segments from the same video_id
    """
    sampled_idxs_order = []
    unorder_speaker_partition_df = speaker_df.loc[sampled_idxs].copy()
    while len(sampled_idxs_order) < sample_size:
        for video_id in unorder_speaker_partition_df.video_id.unique():
            df_to_choose = unorder_speaker_partition_df[(unorder_speaker_partition_df.video_id == video_id) & (~unorder_speaker_partition_df.index.isin(sampled_idxs_order))]
            if df_to_choose.empty:
                continue
            idx = np.random.choice(
                a=df_to_choose.index, size=1, replace=False
            )[0]
            sampled_idxs_order.append(idx)
    return sampled_idxs_order

# %%
df = state['dataset_metadata'].copy()
dfs = []
for speaker_id in tqdm(alternated_list):
    # Process sample sizes for speaker id once, because the df will get modified
    speaker_df = df[df.speaker_id == speaker_id].copy()
    sample_sizes = process_sample_sizes(proportions=proportions, speaker_df=speaker_df)

    for partition, sample_size in sample_sizes.items():
        if partition != remainder_k:
            speaker_df = df[df.speaker_id == speaker_id].copy()
            speaker_df.drop("Set", axis=1, inplace=True)

            sampled_idxs = np.random.choice(
                a=speaker_df.index, size=sample_size, replace=False
            )

            sampled_idxs_order = sort_idx_alternating_video_ids(speaker_df=speaker_df, sampled_idxs=sampled_idxs, sample_size=sample_size)

            assert len(sampled_idxs) == len(sampled_idxs_order) == sample_size

            speaker_partition_df = speaker_df.loc[sampled_idxs_order]

            df = df[~df.index.isin(speaker_partition_df.index)]  # Remove chosen
            speaker_partition_df['set'] = partition
            dfs.append(speaker_partition_df)


    if remainder_k is not None:
        speaker_df = df[df.speaker_id == speaker_id].copy() # Remaining speaker df
        sampled_idxs_order = sort_idx_alternating_video_ids(speaker_df=speaker_df, sampled_idxs=speaker_df.index, sample_size=len(speaker_df))
        speaker_partition_df = speaker_df.loc[sampled_idxs_order]
        speaker_partition_df.drop("Set", axis=1, inplace=True)
        speaker_partition_df['set'] = remainder_k
        df = df[~df.index.isin(speaker_partition_df.index)]  # Remove chosen
        dfs.append(speaker_partition_df)

splits_df = pd.concat(dfs)
# Out:
#  ... (more hidden) ...

# %%
assert len(splits_df) == len(state['dataset_metadata'])

# %%
df = pd.read_csv("/home/eernst/Voxceleb1/splits.csv")
df
# Out:
#         Unnamed: 0   index                                           filename  \
# 0           141482  141482  /datasets/Voxceleb1/wav/id10986/Gq881M1WnKM/00...
# 1           141696  141696  /datasets/Voxceleb1/wav/id10986/6SBGrr4iFp0/00...
# 2           141820  141820  /datasets/Voxceleb1/wav/id10986/lFEBeMFuL_M/00...
# 3           141645  141645  /datasets/Voxceleb1/wav/id10986/KH-yJAsKo1Q/00...
# 4           141389  141389  /datasets/Voxceleb1/wav/id10986/sOlWHKGy-SY/00...
# ...            ...     ...                                                ...
# 153511      138942  138942  /datasets/Voxceleb1/wav/id11229/zO6sDDC8jDw/00...
# 153512      138911  138911  /datasets/Voxceleb1/wav/id11229/hMMde0Vtg-M/00...
# 153513      138922  138922  /datasets/Voxceleb1/wav/id11229/AiJinimEdKA/00...
# 153514      138943  138943  /datasets/Voxceleb1/wav/id11229/zO6sDDC8jDw/00...
# 153515      138920  138920  /datasets/Voxceleb1/wav/id11229/AiJinimEdKA/00...
#
#            sr  channels  frames   duration speaker_id     video_id  \
# 0       16000         1  111361   6.960063    id10986  Gq881M1WnKM
# 1       16000         1   65921   4.120063    id10986  6SBGrr4iFp0
# 2       16000         1   88961   5.560062    id10986  lFEBeMFuL_M
# 3       16000         1  553601  34.600062    id10986  KH-yJAsKo1Q
# 4       16000         1  144641   9.040062    id10986  sOlWHKGy-SY
# ...       ...       ...     ...        ...        ...          ...
# 153511  16000         1  120961   7.560062    id11229  zO6sDDC8jDw
# 153512  16000         1  136321   8.520062    id11229  hMMde0Vtg-M
# 153513  16000         1  299521  18.720063    id11229  AiJinimEdKA
# 153514  16000         1  126081   7.880063    id11229  zO6sDDC8jDw
# 153515  16000         1  178561  11.160063    id11229  AiJinimEdKA
#
#         segment_id  VGGFace1 ID Gender Nationality    dataset  \
# 0                3   Rob_Reiner      m         USA  voxceleb1
# 1               30   Rob_Reiner      m         USA  voxceleb1
# 2               17   Rob_Reiner      m         USA  voxceleb1
# 3               12   Rob_Reiner      m         USA  voxceleb1
# 4               66   Rob_Reiner      m         USA  voxceleb1
# ...            ...          ...    ...         ...        ...
# 153511           7  Will_Mellor      m          UK  voxceleb1
# 153512           2  Will_Mellor      m          UK  voxceleb1
# 153513           1  Will_Mellor      m          UK  voxceleb1
# 153514           4  Will_Mellor      m          UK  voxceleb1
# 153515           5  Will_Mellor      m          UK  voxceleb1
#
#                                  rel_path         set
# 0       wav/id10986/Gq881M1WnKM/00003.wav  validation
# 1       wav/id10986/6SBGrr4iFp0/00030.wav  validation
# 2       wav/id10986/lFEBeMFuL_M/00017.wav  validation
# 3       wav/id10986/KH-yJAsKo1Q/00012.wav  validation
# 4       wav/id10986/sOlWHKGy-SY/00066.wav  validation
# ...                                   ...         ...
# 153511  wav/id11229/zO6sDDC8jDw/00007.wav       train
# 153512  wav/id11229/hMMde0Vtg-M/00002.wav       train
# 153513  wav/id11229/AiJinimEdKA/00001.wav       train
# 153514  wav/id11229/zO6sDDC8jDw/00004.wav       train
# 153515  wav/id11229/AiJinimEdKA/00005.wav       train
#
# [153516 rows x 16 columns]

# %%
len(state['dataset_metadata'])
# Out:
# 153516

# %%
df4.groupby(['speaker_id']).size().describe()
# Out:
# count     100.000000
# mean      308.860000
# std       105.420564
# min       216.000000
# 25%       254.000000
# 50%       283.000000
# 75%       330.500000
# max      1002.000000
# dtype: float64

# %%
speaker_df = df.loc[sampled_idxs][df.speaker_id == "id10986"].copy()
d = speaker_df.groupby(['video_id']).size().to_dict()
# Out:
# /tmp/ipykernel_45916/300627077.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   speaker_df = df.loc[sampled_idxs][df.speaker_id == "id10986"].copy()

# %%
len(d)
# Out:
# 23

# %%
d
# Out:
# {'33NaEPsiFEA': 2,
#  '4p9Fm05hlIM': 3,
#  '6SBGrr4iFp0': 11,
#  '79oWAvMcAm0': 1,
#  'GPPBWbOC1FM': 3,
#  'Gq881M1WnKM': 3,
#  'Hyck_yynhF4': 9,
#  'KH-yJAsKo1Q': 8,
#  'KZVJwFblEUo': 1,
#  'Pqwj7Sk4Qyw': 1,
#  'SfYt6Y6vrOI': 1,
#  'Vu__sFrtFfY': 1,
#  'Vzqmi3MAixQ': 15,
#  'XaXt-hdv2Js': 1,
#  'd8H0ZdING7Y': 1,
#  'eWvntayRfe8': 15,
#  'fFnHb9jzYwU': 1,
#  'lFEBeMFuL_M': 15,
#  'sOlWHKGy-SY': 15,
#  'tj0Mw2xTE74': 3,
#  'w7DmOHDIMQ8': 16,
#  'wJ_YINYHBwY': 8,
#  'xFTIClN5z70': 16}

# %% [markdown]
# ## Heuristic to separate video_ids for validation and test

# %%
df = state['dataset_metadata'].copy()
proportions = {"train": 0.75, "validation": 0.15, "test": 0.15}
RETRIES_DEFAULT = 30
dfs = []
extra_audios_list = [i for i in range(10)] + [i for i in range(-1, -6, -1)]
extra_audios_i = 0
np.random.seed(42)
for speaker_id in alternated_list:
    sample_sizes = {}
    speaker_df = df[df.speaker_id == speaker_id].copy()
    for partition, v in proportions.items():
        sample_sizes[partition] = int(len(speaker_df) * v)
    
    for partition, v in proportions.items():
        if partition != "train":
            print((speaker_id, partition))
            speaker_df = df[df.speaker_id == speaker_id].copy()
            speaker_df.drop("Set", axis=1, inplace=True)

            sample_size = sample_sizes[partition]
            # Get group of video ids that sum sample_size + extra_audios (desirably extra_audios=0)
            # This is a naive approach to the knapsack problem
            video_id_to_audios_count = speaker_df.groupby(['video_id']).size().to_dict()
            print(video_id_to_audios_count)
            extra_audios_i = 0
            retries = RETRIES_DEFAULT
            found_group_of_videos = False
            while not found_group_of_videos:
                chosen_videos = []
                videos_sum = 0
                print(f"RETRY: {retries}")
                extra_audios = extra_audios_list[extra_audios_i]
                while videos_sum < sample_size + extra_audios:
                    remaining_audios = sample_size + extra_audios - videos_sum
                    print(f"remaining_audios: {remaining_audios} with extra videos {extra_audios} video sum {videos_sum}")
                    video_id_candidates = [
                        video_id
                        for video_id, audio_count in video_id_to_audios_count.items()
                        if video_id not in chosen_videos and audio_count <= remaining_audios
                    ]
                    if not video_id_candidates:
                        break

                    probabilities = [
                        audio_count # As all are less than remaining_audios, the bigger the closer to remaining_audios
                        for video_id, audio_count in video_id_to_audios_count.items()
                        if video_id in video_id_candidates
                    ]
                    normalized_probabilities = [prob / sum(probabilities) for prob in probabilities]
                    video_id = np.random.choice(a=video_id_candidates, size=1, replace=False, p=normalized_probabilities)[0]
                    chosen_videos.append(video_id)
                    videos_sum += video_id_to_audios_count[video_id]
                    print(f"chose: {video_id} with count {video_id_to_audios_count[video_id]} sum {videos_sum}")

                if videos_sum == sample_size + extra_audios:
                    found_group_of_videos = True
                elif retries == 0:
                    retries = RETRIES_DEFAULT
                    extra_audios_i += 1
                else:
                    retries -= 1

                if extra_audios_i >= len(extra_audios_list) or extra_audios / sample_size > 0.8:
                    raise ValueError(speaker_id)
            
            speaker_partition_df = speaker_df[speaker_df.video_id.isin(chosen_videos)].copy()
            df = df[~df.index.isin(speaker_partition_df.index)]  # Remove chosen
            speaker_partition_df['set'] = partition
            dfs.append(speaker_partition_df)

    # Train partition
    print((speaker_id, "train"))
    speaker_partition_df = df[df.speaker_id == speaker_id].copy()
    speaker_partition_df.drop("Set", axis=1, inplace=True)
    speaker_partition_df['set'] = "train"
    df = df[~df.index.isin(speaker_partition_df.index)]  # Remove chosen
    dfs.append(speaker_partition_df)
# Out:
# ('id10986', 'validation')
# {'33NaEPsiFEA': 4, '4p9Fm05hlIM': 11, '6SBGrr4iFp0': 50, '6c5ljEc2Clo': 3, '79oWAvMcAm0': 5, '94JZBdGzoxc': 1, 'GPPBWbOC1FM': 19, 'Gq881M1WnKM': 18, 'Hyck_yynhF4': 62, 'KH-yJAsKo1Q': 46, 'KZVJwFblEUo': 1, 'Pqwj7Sk4Qyw': 1, 'SfYt6Y6vrOI': 5, 'Vu__sFrtFfY': 5, 'Vzqmi3MAixQ': 127, 'XBqRyPiDJ9k': 1, 'XaXt-hdv2Js': 10, 'b7NFJBhE9EY': 5, 'd8H0ZdING7Y': 3, 'eWvntayRfe8': 89, 'fFnHb9jzYwU': 9, 'g7SptlsGbaA': 8, 'lFEBeMFuL_M': 131, 'p5qFkL8yVuI': 11, 's2077pq_vdY': 6, 'sOlWHKGy-SY': 122, 'tj0Mw2xTE74': 12, 'w7DmOHDIMQ8': 99, 'wJ_YINYHBwY': 25, 'wyklNur-auI': 1, 'xFTIClN5z70': 111, 'xmf3xBGKSoA': 1}
# RETRY: 30
# remaining_audios: 150 with extra videos 0 video sum 0
# chose: d8H0ZdING7Y with count 3 sum 3
# remaining_audios: 147 with extra videos 0 video sum 3
# chose: xFTIClN5z70 with count 111 sum 114
# remaining_audios: 36 with extra videos 0 video sum 114
# chose: s2077pq_vdY with count 6 sum 120
# remaining_audios: 30 with extra videos 0 video sum 120
# chose: fFnHb9jzYwU with count 9 sum 129
# remaining_audios: 21 with extra videos 0 video sum 129
# chose: 79oWAvMcAm0 with count 5 sum 134
# remaining_audios: 16 with extra videos 0 video sum 134
# chose: 4p9Fm05hlIM with count 11 sum 145
# remaining_audios: 5 with extra videos 0 video sum 145
# chose: 33NaEPsiFEA with count 4 sum 149
# remaining_audios: 1 with extra videos 0 video sum 149
# chose: xmf3xBGKSoA with count 1 sum 150
# ('id10986', 'test')
# {'6SBGrr4iFp0': 50, '6c5ljEc2Clo': 3, '94JZBdGzoxc': 1, 'GPPBWbOC1FM': 19, 'Gq881M1WnKM': 18, 'Hyck_yynhF4': 62, 'KH-yJAsKo1Q': 46, 'KZVJwFblEUo': 1, 'Pqwj7Sk4Qyw': 1, 'SfYt6Y6vrOI': 5, 'Vu__sFrtFfY': 5, 'Vzqmi3MAixQ': 127, 'XBqRyPiDJ9k': 1, 'XaXt-hdv2Js': 10, 'b7NFJBhE9EY': 5, 'eWvntayRfe8': 89, 'g7SptlsGbaA': 8, 'lFEBeMFuL_M': 131, 'p5qFkL8yVuI': 11, 'sOlWHKGy-SY': 122, 'tj0Mw2xTE74': 12, 'w7DmOHDIMQ8': 99, 'wJ_YINYHBwY': 25, 'wyklNur-auI': 1}
# RETRY: 30
# remaining_audios: 150 with extra videos 0 video sum 0
# chose: lFEBeMFuL_M with count 131 sum 131
# remaining_audios: 19 with extra videos 0 video sum 131
# chose: g7SptlsGbaA with count 8 sum 139
# remaining_audios: 11 with extra videos 0 video sum 139
# chose: 6c5ljEc2Clo with count 3 sum 142
# remaining_audios: 8 with extra videos 0 video sum 142
# chose: wyklNur-auI with count 1 sum 143
# remaining_audios: 7 with extra videos 0 video sum 143
# chose: b7NFJBhE9EY with count 5 sum 148
# remaining_audios: 2 with extra videos 0 video sum 148
# chose: 94JZBdGzoxc with count 1 sum 149
# remaining_audios: 1 with extra videos 0 video sum 149
# chose: KZVJwFblEUo with count 1 sum 150
# ('id10986', 'train')
# ('id10343', 'validation')
# {'0SKxyxFY_18': 1, '8zl5qeF0aqs': 1, 'DbN5tyZ5IvE': 16, 'HoV3UgQBvh4': 18, 'NQxx1WJcaE8': 66, 'TFIZ9vWg6EE': 12, 'TmFxFmrcngk': 23, 'VHJa1y8stE0': 18, 'WcAnh00sWKs': 7, 'Wy8sFgdylRc': 134, 'ZerQ52w7sjI': 1, 'dAa_SBA0QHY': 1, 'fgM5073sfx8': 3, 'fvDz-WCUv20': 7, 'kxR0IoG6oKk': 9, 'nQZLZ8uoddE': 14, 'oLvhsNuDnFI': 1, 'pCDWKHjQjso': 4, 'yBAUUw9ovKw': 23, 'yJ5DFQQbOZU': 22}
# RETRY: 30
# remaining_audios: 57 with extra videos 0 video sum 0
# chose: HoV3UgQBvh4 with count 18 sum 18
# remaining_audios: 39 with extra videos 0 video sum 18
# chose: TmFxFmrcngk with count 23 sum 41
# remaining_audios: 16 with extra videos 0 video sum 41
# chose: fgM5073sfx8 with count 3 sum 44
# remaining_audios: 13 with extra videos 0 video sum 44
# chose: WcAnh00sWKs with count 7 sum 51
# remaining_audios: 6 with extra videos 0 video sum 51
# chose: ZerQ52w7sjI with count 1 sum 52
# remaining_audios: 5 with extra videos 0 video sum 52
# chose: pCDWKHjQjso with count 4 sum 56
# remaining_audios: 1 with extra videos 0 video sum 56
# chose: 0SKxyxFY_18 with count 1 sum 57
# ('id10343', 'test')
# {'8zl5qeF0aqs': 1, 'DbN5tyZ5IvE': 16, 'NQxx1WJcaE8': 66, 'TFIZ9vWg6EE': 12, 'VHJa1y8stE0': 18, 'Wy8sFgdylRc': 134, 'dAa_SBA0QHY': 1, 'fvDz-WCUv20': 7, 'kxR0IoG6oKk': 9, 'nQZLZ8uoddE': 14, 'oLvhsNuDnFI': 1, 'yBAUUw9ovKw': 23, 'yJ5DFQQbOZU': 22}
# RETRY: 30
# remaining_audios: 57 with extra videos 0 video sum 0
# chose: VHJa1y8stE0 with count 18 sum 18
# remaining_audios: 39 with extra videos 0 video sum 18
# chose: kxR0IoG6oKk with count 9 sum 27
# remaining_audios: 30 with extra videos 0 video sum 27
# chose: nQZLZ8uoddE with count 14 sum 41
# remaining_audios: 16 with extra videos 0 video sum 41
# chose: dAa_SBA0QHY with count 1 sum 42
# remaining_audios: 15 with extra videos 0 video sum 42
# chose: TFIZ9vWg6EE with count 12 sum 54
# remaining_audios: 3 with extra videos 0 video sum 54
# chose: oLvhsNuDnFI with count 1 sum 55
# remaining_audios: 2 with extra videos 0 video sum 55
# chose: 8zl5qeF0aqs with count 1 sum 56
# remaining_audios: 1 with extra videos 0 video sum 56
# RETRY: 29
# remaining_audios: 57 with extra videos 0 video sum 0
# chose: DbN5tyZ5IvE with count 16 sum 16
# remaining_audios: 41 with extra videos 0 video sum 16
# chose: yBAUUw9ovKw with count 23 sum 39
# remaining_audios: 18 with extra videos 0 video sum 39
# chose: TFIZ9vWg6EE with count 12 sum 51
# remaining_audios: 6 with extra videos 0 video sum 51
# chose: 8zl5qeF0aqs with count 1 sum 52
# remaining_audios: 5 with extra videos 0 video sum 52
# chose: oLvhsNuDnFI with count 1 sum 53
# remaining_audios: 4 with extra videos 0 video sum 53
# chose: dAa_SBA0QHY with count 1 sum 54
# remaining_audios: 3 with extra videos 0 video sum 54
# RETRY: 28
# remaining_audios: 57 with extra videos 0 video sum 0
# chose: yBAUUw9ovKw with count 23 sum 23
# remaining_audios: 34 with extra videos 0 video sum 23
# chose: VHJa1y8stE0 with count 18 sum 41
# remaining_audios: 16 with extra videos 0 video sum 41
# chose: DbN5tyZ5IvE with count 16 sum 57
# ('id10343', 'train')
# ('id10096', 'validation')
# {'0ApAnZOmR2I': 17, '5Ciy1E1gYRc': 105, 'F8tju2wuDEs': 117, 'Jnurf8ZtV-E': 2, 'KSpeW7Slm9Q': 6, 'NTHlOJY58Hc': 109, 'Oq9pQ9eVT1s': 3, 'cII4Z0sCl9Y': 102, 'cnQptIJlqAw': 88, 'gCXY29GK-W4': 5, 'ljMIDBpFkHs': 6, 'oz7wyQ3uo88': 1, 'qMU3f7XiSlE': 81, 'w02jeR_pJZ0': 8, 'w2lsTCrQMU8': 2, 'yK2T5SQSzPw': 4}
# RETRY: 30
# remaining_audios: 98 with extra videos 0 video sum 0
# chose: qMU3f7XiSlE with count 81 sum 81
# remaining_audios: 17 with extra videos 0 video sum 81
# chose: KSpeW7Slm9Q with count 6 sum 87
# remaining_audios: 11 with extra videos 0 video sum 87
# chose: Oq9pQ9eVT1s with count 3 sum 90
# remaining_audios: 8 with extra videos 0 video sum 90
# chose: oz7wyQ3uo88 with count 1 sum 91
# remaining_audios: 7 with extra videos 0 video sum 91
# chose: Jnurf8ZtV-E with count 2 sum 93
# remaining_audios: 5 with extra videos 0 video sum 93
# chose: yK2T5SQSzPw with count 4 sum 97
# remaining_audios: 1 with extra videos 0 video sum 97
# RETRY: 29
# remaining_audios: 98 with extra videos 0 video sum 0
# chose: cnQptIJlqAw with count 88 sum 88
# remaining_audios: 10 with extra videos 0 video sum 88
# chose: w02jeR_pJZ0 with count 8 sum 96
# remaining_audios: 2 with extra videos 0 video sum 96
# chose: Jnurf8ZtV-E with count 2 sum 98
# ('id10096', 'test')
# {'0ApAnZOmR2I': 17, '5Ciy1E1gYRc': 105, 'F8tju2wuDEs': 117, 'KSpeW7Slm9Q': 6, 'NTHlOJY58Hc': 109, 'Oq9pQ9eVT1s': 3, 'cII4Z0sCl9Y': 102, 'gCXY29GK-W4': 5, 'ljMIDBpFkHs': 6, 'oz7wyQ3uo88': 1, 'qMU3f7XiSlE': 81, 'w2lsTCrQMU8': 2, 'yK2T5SQSzPw': 4}
# RETRY: 30
# remaining_audios: 98 with extra videos 0 video sum 0
# chose: qMU3f7XiSlE with count 81 sum 81
# remaining_audios: 17 with extra videos 0 video sum 81
# chose: Oq9pQ9eVT1s with count 3 sum 84
# remaining_audios: 14 with extra videos 0 video sum 84
# chose: KSpeW7Slm9Q with count 6 sum 90
# remaining_audios: 8 with extra videos 0 video sum 90
# chose: yK2T5SQSzPw with count 4 sum 94
# remaining_audios: 4 with extra videos 0 video sum 94
# chose: w2lsTCrQMU8 with count 2 sum 96
# remaining_audios: 2 with extra videos 0 video sum 96
# chose: oz7wyQ3uo88 with count 1 sum 97
# remaining_audios: 1 with extra videos 0 video sum 97
# RETRY: 29
# remaining_audios: 98 with extra videos 0 video sum 0
# chose: qMU3f7XiSlE with count 81 sum 81
# remaining_audios: 17 with extra videos 0 video sum 81
# chose: gCXY29GK-W4 with count 5 sum 86
# remaining_audios: 12 with extra videos 0 video sum 86
# chose: yK2T5SQSzPw with count 4 sum 90
# remaining_audios: 8 with extra videos 0 video sum 90
# chose: KSpeW7Slm9Q with count 6 sum 96
# remaining_audios: 2 with extra videos 0 video sum 96
# chose: oz7wyQ3uo88 with count 1 sum 97
# remaining_audios: 1 with extra videos 0 video sum 97
# RETRY: 28
# remaining_audios: 98 with extra videos 0 video sum 0
# chose: 0ApAnZOmR2I with count 17 sum 17
# remaining_audios: 81 with extra videos 0 video sum 17
# chose: qMU3f7XiSlE with count 81 sum 98
# ('id10096', 'train')
# ('id10715', 'validation')
# {'1Cq17O_b5PI': 13, '1caBxE8ab_8': 1, '53TPX-lAnQs': 13, '61aqe1l7-B4': 20, '6JumsRzVRGE': 1, '95D3xoYVIKw': 4, '9VPK7BusHDI': 7, 'E7VlCtXRSXc': 16, 'IOL7cbC-i18': 18, 'Rc2tztXAw4w': 38, 'THmbs_MvkH8': 8, 'WIxJnSvFfY4': 26, 'akGTL1WMbVI': 27, 'b7UWHI07PiE': 13, 'bFBEHF1SWeQ': 7, 'oYzKZelxKDI': 20, 'pCkz5N0a0RY': 15, 'qexwrS8HwvI': 7, 'qxoV_gJDHAE': 16, 'rvFzQocj09k': 25, 'rz2nxNrhGtk': 10, 'vLZ9oqNFPOY': 8, 've6qA-6_Q5g': 32, 'vlozz6EwggI': 13, 'w38dZScQ9Fc': 2, 'zN-wTTKcSPM': 14}
# RETRY: 30
# remaining_audios: 56 with extra videos 0 video sum 0
# chose: WIxJnSvFfY4 with count 26 sum 26
# remaining_audios: 30 with extra videos 0 video sum 26
# chose: IOL7cbC-i18 with count 18 sum 44
# remaining_audios: 12 with extra videos 0 video sum 44
# chose: vLZ9oqNFPOY with count 8 sum 52
# remaining_audios: 4 with extra videos 0 video sum 52
# chose: 95D3xoYVIKw with count 4 sum 56
# ('id10715', 'test')
# {'1Cq17O_b5PI': 13, '1caBxE8ab_8': 1, '53TPX-lAnQs': 13, '61aqe1l7-B4': 20, '6JumsRzVRGE': 1, '9VPK7BusHDI': 7, 'E7VlCtXRSXc': 16, 'Rc2tztXAw4w': 38, 'THmbs_MvkH8': 8, 'akGTL1WMbVI': 27, 'b7UWHI07PiE': 13, 'bFBEHF1SWeQ': 7, 'oYzKZelxKDI': 20, 'pCkz5N0a0RY': 15, 'qexwrS8HwvI': 7, 'qxoV_gJDHAE': 16, 'rvFzQocj09k': 25, 'rz2nxNrhGtk': 10, 've6qA-6_Q5g': 32, 'vlozz6EwggI': 13, 'w38dZScQ9Fc': 2, 'zN-wTTKcSPM': 14}
# RETRY: 30
# remaining_audios: 56 with extra videos 0 video sum 0
# chose: Rc2tztXAw4w with count 38 sum 38
# remaining_audios: 18 with extra videos 0 video sum 38
# chose: pCkz5N0a0RY with count 15 sum 53
# remaining_audios: 3 with extra videos 0 video sum 53
# chose: 1caBxE8ab_8 with count 1 sum 54
# remaining_audios: 2 with extra videos 0 video sum 54
# chose: w38dZScQ9Fc with count 2 sum 56
# ('id10715', 'train')
# ('id10020', 'validation')
# {'1elTcNGC3q8': 46, '37HXBdOMKOk': 37, '70e-rrF1NnQ': 91, '7H3a2ZhOt1U': 4, '986AHSerdyI': 7, 'A_blsQbRRC8': 12, 'Gi11Fgbjqdc': 6, 'HELG9IIqhBE': 12, 'H_NA9yw_kVE': 5, 'NCFG73oAvUE': 20, 'PzSCbADJSzg': 6, 'RSevwDj13_g': 17, 'Sj407D6anmI': 8, 'Tv92FNzH3Qc': 83, 'UilhQH32RHA': 24, 'aGVMDWHASho': 6, 'hun71wPQvlI': 29, 'iNwAECjAAAM': 61, 'jPGRVcnoOWY': 22, 'jrZbWZ6Y8Jk': 7, 'mcFRwLcBrQA': 23, 'miCK2SKm3XE': 8, 'nW-4wrt332E': 2, 'oIn5J6YJAmQ': 15, 'xHcXn2RLNS8': 8, 'zFyun6tYFaw': 5, 'zHAGrIElkDU': 25}
# RETRY: 30
# remaining_audios: 88 with extra videos 0 video sum 0
# chose: 1elTcNGC3q8 with count 46 sum 46
# remaining_audios: 42 with extra videos 0 video sum 46
# chose: zHAGrIElkDU with count 25 sum 71
# remaining_audios: 17 with extra videos 0 video sum 71
# chose: nW-4wrt332E with count 2 sum 73
# remaining_audios: 15 with extra videos 0 video sum 73
# chose: A_blsQbRRC8 with count 12 sum 85
# remaining_audios: 3 with extra videos 0 video sum 85
# RETRY: 29
# remaining_audios: 88 with extra videos 0 video sum 0
# chose: 1elTcNGC3q8 with count 46 sum 46
# remaining_audios: 42 with extra videos 0 video sum 46
# chose: miCK2SKm3XE with count 8 sum 54
# remaining_audios: 34 with extra videos 0 video sum 54
# chose: mcFRwLcBrQA with count 23 sum 77
# remaining_audios: 11 with extra videos 0 video sum 77
# chose: jrZbWZ6Y8Jk with count 7 sum 84
# remaining_audios: 4 with extra videos 0 video sum 84
# chose: nW-4wrt332E with count 2 sum 86
# remaining_audios: 2 with extra videos 0 video sum 86
# RETRY: 28
# remaining_audios: 88 with extra videos 0 video sum 0
# chose: 1elTcNGC3q8 with count 46 sum 46
# remaining_audios: 42 with extra videos 0 video sum 46
# chose: RSevwDj13_g with count 17 sum 63
# remaining_audios: 25 with extra videos 0 video sum 63
# chose: Gi11Fgbjqdc with count 6 sum 69
# remaining_audios: 19 with extra videos 0 video sum 69
# chose: oIn5J6YJAmQ with count 15 sum 84
# remaining_audios: 4 with extra videos 0 video sum 84
# chose: 7H3a2ZhOt1U with count 4 sum 88
# ('id10020', 'test')
# {'37HXBdOMKOk': 37, '70e-rrF1NnQ': 91, '986AHSerdyI': 7, 'A_blsQbRRC8': 12, 'HELG9IIqhBE': 12, 'H_NA9yw_kVE': 5, 'NCFG73oAvUE': 20, 'PzSCbADJSzg': 6, 'Sj407D6anmI': 8, 'Tv92FNzH3Qc': 83, 'UilhQH32RHA': 24, 'aGVMDWHASho': 6, 'hun71wPQvlI': 29, 'iNwAECjAAAM': 61, 'jPGRVcnoOWY': 22, 'jrZbWZ6Y8Jk': 7, 'mcFRwLcBrQA': 23, 'miCK2SKm3XE': 8, 'nW-4wrt332E': 2, 'xHcXn2RLNS8': 8, 'zFyun6tYFaw': 5, 'zHAGrIElkDU': 25}
# RETRY: 30
# remaining_audios: 88 with extra videos 0 video sum 0
# chose: Tv92FNzH3Qc with count 83 sum 83
# remaining_audios: 5 with extra videos 0 video sum 83
# chose: H_NA9yw_kVE with count 5 sum 88
# ('id10020', 'train')
# ('id11088', 'validation')
# {'84v8I-I8LVA': 4, 'Acz7RtcUXkk': 5, 'Bsb2L2sGBb8': 1, 'DutYuq39XEE': 56, 'LTvynCSkhQ8': 5, 'Ldmp1pdL3fs': 2, 'PjFlQU0sCCQ': 1, 'Q0YU_S7jFhA': 174, 'ShDFMbz6y-o': 4, 'URehJMHN6hI': 4, 'Uud38zrOMRI': 2, 'gmj-azFbpkA': 1, 'k8pBR3o0bSg': 67, 'm10Me1BG06g': 5, 'qVruVasy3ck': 5, 'qlIN7mVty3c': 6, 'sSPuoJJOd8Q': 1, 'uuHFwHdzlF8': 5, 'x2m6UT2PEv0': 15}
# RETRY: 30
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: ShDFMbz6y-o with count 4 sum 4
# remaining_audios: 50 with extra videos 0 video sum 4
# chose: URehJMHN6hI with count 4 sum 8
# remaining_audios: 46 with extra videos 0 video sum 8
# chose: uuHFwHdzlF8 with count 5 sum 13
# remaining_audios: 41 with extra videos 0 video sum 13
# chose: qlIN7mVty3c with count 6 sum 19
# remaining_audios: 35 with extra videos 0 video sum 19
# chose: x2m6UT2PEv0 with count 15 sum 34
# remaining_audios: 20 with extra videos 0 video sum 34
# chose: Ldmp1pdL3fs with count 2 sum 36
# remaining_audios: 18 with extra videos 0 video sum 36
# chose: 84v8I-I8LVA with count 4 sum 40
# remaining_audios: 14 with extra videos 0 video sum 40
# chose: m10Me1BG06g with count 5 sum 45
# remaining_audios: 9 with extra videos 0 video sum 45
# chose: qVruVasy3ck with count 5 sum 50
# remaining_audios: 4 with extra videos 0 video sum 50
# chose: Uud38zrOMRI with count 2 sum 52
# remaining_audios: 2 with extra videos 0 video sum 52
# chose: sSPuoJJOd8Q with count 1 sum 53
# remaining_audios: 1 with extra videos 0 video sum 53
# chose: PjFlQU0sCCQ with count 1 sum 54
# ('id11088', 'test')
# {'Acz7RtcUXkk': 5, 'Bsb2L2sGBb8': 1, 'DutYuq39XEE': 56, 'LTvynCSkhQ8': 5, 'Q0YU_S7jFhA': 174, 'gmj-azFbpkA': 1, 'k8pBR3o0bSg': 67}
# RETRY: 30
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 29
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 28
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 27
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Bsb2L2sGBb8 with count 1 sum 6
# remaining_audios: 48 with extra videos 0 video sum 6
# chose: LTvynCSkhQ8 with count 5 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 26
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: gmj-azFbpkA with count 1 sum 1
# remaining_audios: 53 with extra videos 0 video sum 1
# chose: LTvynCSkhQ8 with count 5 sum 6
# remaining_audios: 48 with extra videos 0 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 25
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 24
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: gmj-azFbpkA with count 1 sum 6
# remaining_audios: 48 with extra videos 0 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 23
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 22
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 21
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 20
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 19
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: gmj-azFbpkA with count 1 sum 1
# remaining_audios: 53 with extra videos 0 video sum 1
# chose: Acz7RtcUXkk with count 5 sum 6
# remaining_audios: 48 with extra videos 0 video sum 6
# chose: LTvynCSkhQ8 with count 5 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 18
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Bsb2L2sGBb8 with count 1 sum 6
# remaining_audios: 48 with extra videos 0 video sum 6
# chose: LTvynCSkhQ8 with count 5 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 17
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 16
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 15
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Bsb2L2sGBb8 with count 1 sum 6
# remaining_audios: 48 with extra videos 0 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 14
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 13
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 12
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 11
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 10
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 9
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Bsb2L2sGBb8 with count 1 sum 6
# remaining_audios: 48 with extra videos 0 video sum 6
# chose: gmj-azFbpkA with count 1 sum 7
# remaining_audios: 47 with extra videos 0 video sum 7
# chose: LTvynCSkhQ8 with count 5 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 8
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 7
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 6
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 5
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: gmj-azFbpkA with count 1 sum 6
# remaining_audios: 48 with extra videos 0 video sum 6
# chose: Bsb2L2sGBb8 with count 1 sum 7
# remaining_audios: 47 with extra videos 0 video sum 7
# chose: Acz7RtcUXkk with count 5 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 4
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 3
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 2
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 1
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 0
# remaining_audios: 54 with extra videos 0 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 49 with extra videos 0 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 44 with extra videos 0 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 43 with extra videos 0 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 42 with extra videos 0 video sum 12
# RETRY: 30
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 29
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 28
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 27
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 26
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Bsb2L2sGBb8 with count 1 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: LTvynCSkhQ8 with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 25
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: gmj-azFbpkA with count 1 sum 1
# remaining_audios: 54 with extra videos 1 video sum 1
# chose: LTvynCSkhQ8 with count 5 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Bsb2L2sGBb8 with count 1 sum 7
# remaining_audios: 48 with extra videos 1 video sum 7
# chose: Acz7RtcUXkk with count 5 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 24
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: gmj-azFbpkA with count 1 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: LTvynCSkhQ8 with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 23
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: gmj-azFbpkA with count 1 sum 1
# remaining_audios: 54 with extra videos 1 video sum 1
# chose: LTvynCSkhQ8 with count 5 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 22
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 21
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: gmj-azFbpkA with count 1 sum 1
# remaining_audios: 54 with extra videos 1 video sum 1
# chose: LTvynCSkhQ8 with count 5 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 20
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: gmj-azFbpkA with count 1 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 19
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Bsb2L2sGBb8 with count 1 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 18
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 17
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: gmj-azFbpkA with count 1 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 16
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 15
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 14
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 13
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 12
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 11
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 10
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: gmj-azFbpkA with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 9
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: gmj-azFbpkA with count 1 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 8
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 7
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: gmj-azFbpkA with count 1 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: LTvynCSkhQ8 with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 6
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: LTvynCSkhQ8 with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 5
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Bsb2L2sGBb8 with count 1 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 4
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: gmj-azFbpkA with count 1 sum 1
# remaining_audios: 54 with extra videos 1 video sum 1
# chose: LTvynCSkhQ8 with count 5 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: Bsb2L2sGBb8 with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 3
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Bsb2L2sGBb8 with count 1 sum 1
# remaining_audios: 54 with extra videos 1 video sum 1
# chose: Acz7RtcUXkk with count 5 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: LTvynCSkhQ8 with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 2
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Acz7RtcUXkk with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Bsb2L2sGBb8 with count 1 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: LTvynCSkhQ8 with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 1
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: LTvynCSkhQ8 with count 5 sum 5
# remaining_audios: 50 with extra videos 1 video sum 5
# chose: Acz7RtcUXkk with count 5 sum 10
# remaining_audios: 45 with extra videos 1 video sum 10
# chose: Bsb2L2sGBb8 with count 1 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 0
# remaining_audios: 55 with extra videos 1 video sum 0
# chose: Bsb2L2sGBb8 with count 1 sum 1
# remaining_audios: 54 with extra videos 1 video sum 1
# chose: LTvynCSkhQ8 with count 5 sum 6
# remaining_audios: 49 with extra videos 1 video sum 6
# chose: Acz7RtcUXkk with count 5 sum 11
# remaining_audios: 44 with extra videos 1 video sum 11
# chose: gmj-azFbpkA with count 1 sum 12
# remaining_audios: 43 with extra videos 1 video sum 12
# RETRY: 30
# remaining_audios: 56 with extra videos 2 video sum 0
# chose: DutYuq39XEE with count 56 sum 56
# ('id11088', 'train')
# ('id11111', 'validation')
# {'0EuI2zU72uo': 2, '2DzM7HKugf8': 22, '5pZ9jx78pVE': 4, '6pscjBGTr_o': 91, '7m99P5xV9zM': 11, 'CqibqD4fJZs': 52, 'G2QZRjUB_VM': 239, 'IgS6YSGvFCw': 8, 'LP1V8G-JPLQ': 2, 'LSMOrOJOB2I': 20, 'NUXCWEOBSn0': 8, 'U2ZZ_EhRfq8': 17, 'V1reuUmFVpk': 4, 'WBZXGxCXhFI': 11, 'Xku_b7a91d4': 4, 'b2O5iVBltbI': 1, 'kqm_5g1FtbY': 20, 'mToS_bd3ohE': 8, 'nsDeDOTMUCA': 16, 'o8oyS_LS920': 3, 'pPn_oazMjh0': 5, 'pqLol6U0XpI': 16, 'v1WGNXllJik': 6}
# RETRY: 30
# remaining_audios: 85 with extra videos 0 video sum 0
# chose: V1reuUmFVpk with count 4 sum 4
# remaining_audios: 81 with extra videos 0 video sum 4
# chose: WBZXGxCXhFI with count 11 sum 15
# remaining_audios: 70 with extra videos 0 video sum 15
# chose: 2DzM7HKugf8 with count 22 sum 37
# remaining_audios: 48 with extra videos 0 video sum 37
# chose: U2ZZ_EhRfq8 with count 17 sum 54
# remaining_audios: 31 with extra videos 0 video sum 54
# chose: mToS_bd3ohE with count 8 sum 62
# remaining_audios: 23 with extra videos 0 video sum 62
# chose: kqm_5g1FtbY with count 20 sum 82
# remaining_audios: 3 with extra videos 0 video sum 82
# chose: o8oyS_LS920 with count 3 sum 85
# ('id11111', 'test')
# {'0EuI2zU72uo': 2, '5pZ9jx78pVE': 4, '6pscjBGTr_o': 91, '7m99P5xV9zM': 11, 'CqibqD4fJZs': 52, 'G2QZRjUB_VM': 239, 'IgS6YSGvFCw': 8, 'LP1V8G-JPLQ': 2, 'LSMOrOJOB2I': 20, 'NUXCWEOBSn0': 8, 'Xku_b7a91d4': 4, 'b2O5iVBltbI': 1, 'nsDeDOTMUCA': 16, 'pPn_oazMjh0': 5, 'pqLol6U0XpI': 16, 'v1WGNXllJik': 6}
# RETRY: 30
# remaining_audios: 85 with extra videos 0 video sum 0
# chose: NUXCWEOBSn0 with count 8 sum 8
# remaining_audios: 77 with extra videos 0 video sum 8
# chose: CqibqD4fJZs with count 52 sum 60
# remaining_audios: 25 with extra videos 0 video sum 60
# chose: 7m99P5xV9zM with count 11 sum 71
# remaining_audios: 14 with extra videos 0 video sum 71
# chose: b2O5iVBltbI with count 1 sum 72
# remaining_audios: 13 with extra videos 0 video sum 72
# chose: 0EuI2zU72uo with count 2 sum 74
# remaining_audios: 11 with extra videos 0 video sum 74
# chose: Xku_b7a91d4 with count 4 sum 78
# remaining_audios: 7 with extra videos 0 video sum 78
# chose: v1WGNXllJik with count 6 sum 84
# remaining_audios: 1 with extra videos 0 video sum 84
# RETRY: 29
# remaining_audios: 85 with extra videos 0 video sum 0
# chose: LSMOrOJOB2I with count 20 sum 20
# remaining_audios: 65 with extra videos 0 video sum 20
# chose: CqibqD4fJZs with count 52 sum 72
# remaining_audios: 13 with extra videos 0 video sum 72
# chose: NUXCWEOBSn0 with count 8 sum 80
# remaining_audios: 5 with extra videos 0 video sum 80
# chose: Xku_b7a91d4 with count 4 sum 84
# remaining_audios: 1 with extra videos 0 video sum 84
# chose: b2O5iVBltbI with count 1 sum 85
# ('id11111', 'train')
# ('id11209', 'validation')
# {'0ZmaCb9ipPA': 5, '2AOADh6xpEQ': 12, '2Q9kg50V7Qk': 22, '2SJgXc18wN8': 5, '3qwnVyBxGrA': 29, '4HcS49qxbdw': 20, '5X5Tgu4SJh8': 8, '9TJA_brL8Ms': 17, 'AfPv4Jhk2NQ': 4, 'GcRqnQGXc_I': 6, 'GuFgYdt1szI': 5, 'K5n4X7NUoZc': 5, 'K97Yo5gYzp4': 27, 'P_ch5zc2wfs': 8, 'W2a_1qzq_VE': 31, 'WYujrLqr28Y': 4, 'XN5MRtyITTE': 2, 'YoUgykRElWw': 13, '_WxNkiCneYs': 4, 'bvSYpZd_xg8': 12, 'hjOIPi_7e90': 1, 'iER54b69dgs': 12, 'ng87j9RtjKc': 29, 'pTCegdOpF8I': 15, 'puXuvYtXGoI': 17, 'qvc1Ih2PEow': 5, 'rBytDC-fu_Q': 2, 'rsdueh8VUDk': 23, 'tAZBItu_vgg': 2, 'yOcBd7KktgM': 6, 'ya32Cn7QY-4': 6}
# RETRY: 30
# remaining_audios: 53 with extra videos 0 video sum 0
# chose: rsdueh8VUDk with count 23 sum 23
# remaining_audios: 30 with extra videos 0 video sum 23
# chose: 9TJA_brL8Ms with count 17 sum 40
# remaining_audios: 13 with extra videos 0 video sum 40
# chose: ya32Cn7QY-4 with count 6 sum 46
# remaining_audios: 7 with extra videos 0 video sum 46
# chose: yOcBd7KktgM with count 6 sum 52
# remaining_audios: 1 with extra videos 0 video sum 52
# chose: hjOIPi_7e90 with count 1 sum 53
# ('id11209', 'test')
# {'0ZmaCb9ipPA': 5, '2AOADh6xpEQ': 12, '2Q9kg50V7Qk': 22, '2SJgXc18wN8': 5, '3qwnVyBxGrA': 29, '4HcS49qxbdw': 20, '5X5Tgu4SJh8': 8, 'AfPv4Jhk2NQ': 4, 'GcRqnQGXc_I': 6, 'GuFgYdt1szI': 5, 'K5n4X7NUoZc': 5, 'K97Yo5gYzp4': 27, 'P_ch5zc2wfs': 8, 'W2a_1qzq_VE': 31, 'WYujrLqr28Y': 4, 'XN5MRtyITTE': 2, 'YoUgykRElWw': 13, '_WxNkiCneYs': 4, 'bvSYpZd_xg8': 12, 'iER54b69dgs': 12, 'ng87j9RtjKc': 29, 'pTCegdOpF8I': 15, 'puXuvYtXGoI': 17, 'qvc1Ih2PEow': 5, 'rBytDC-fu_Q': 2, 'tAZBItu_vgg': 2}
# RETRY: 30
# remaining_audios: 53 with extra videos 0 video sum 0
# chose: 2Q9kg50V7Qk with count 22 sum 22
# remaining_audios: 31 with extra videos 0 video sum 22
# chose: 3qwnVyBxGrA with count 29 sum 51
# remaining_audios: 2 with extra videos 0 video sum 51
# chose: XN5MRtyITTE with count 2 sum 53
# ('id11209', 'train')
# ('id10710', 'validation')
# {'230QPHWW7fM': 20, '5HbYScltf1c': 11, '93koxGjmCjM': 15, '9NZhR93jXyc': 1, 'AYNe4DN8doM': 42, 'AYuvII0Pohw': 3, 'BjNgNDZzH5o': 23, 'FSx8RItIw04': 1, 'KZvs-3dDdgo': 13, 'LQbzUPDwDQQ': 23, 'MFOkBnYGfIM': 5, 'NHbD7SqkQUI': 34, 'Nyi6qwEWBZ8': 1, 'SBC4ewKWQKk': 8, 'Uo0SYjVncmo': 9, 'VFyPhJmxazI': 85, 'Z1v3ocLpCMA': 81, 'b6INQiSm7pQ': 24, 'faoz-h9t4zE': 19, 'fnCgpj9eppQ': 22, 'jDQBmZR2y5g': 7, 'pW5RlH31bQ4': 9, 'ryI2SFdMlkg': 12, 'v8FqD7_YACk': 8, 'vKt2k9KWbTU': 3, 'wCFq52AhH8I': 10}
# RETRY: 30
# remaining_audios: 73 with extra videos 0 video sum 0
# chose: 5HbYScltf1c with count 11 sum 11
# remaining_audios: 62 with extra videos 0 video sum 11
# chose: b6INQiSm7pQ with count 24 sum 35
# remaining_audios: 38 with extra videos 0 video sum 35
# chose: 230QPHWW7fM with count 20 sum 55
# remaining_audios: 18 with extra videos 0 video sum 55
# chose: MFOkBnYGfIM with count 5 sum 60
# remaining_audios: 13 with extra videos 0 video sum 60
# chose: v8FqD7_YACk with count 8 sum 68
# remaining_audios: 5 with extra videos 0 video sum 68
# chose: 9NZhR93jXyc with count 1 sum 69
# remaining_audios: 4 with extra videos 0 video sum 69
# chose: vKt2k9KWbTU with count 3 sum 72
# remaining_audios: 1 with extra videos 0 video sum 72
# chose: FSx8RItIw04 with count 1 sum 73
# ('id10710', 'test')
# {'93koxGjmCjM': 15, 'AYNe4DN8doM': 42, 'AYuvII0Pohw': 3, 'BjNgNDZzH5o': 23, 'KZvs-3dDdgo': 13, 'LQbzUPDwDQQ': 23, 'NHbD7SqkQUI': 34, 'Nyi6qwEWBZ8': 1, 'SBC4ewKWQKk': 8, 'Uo0SYjVncmo': 9, 'VFyPhJmxazI': 85, 'Z1v3ocLpCMA': 81, 'faoz-h9t4zE': 19, 'fnCgpj9eppQ': 22, 'jDQBmZR2y5g': 7, 'pW5RlH31bQ4': 9, 'ryI2SFdMlkg': 12, 'wCFq52AhH8I': 10}
# RETRY: 30
# remaining_audios: 73 with extra videos 0 video sum 0
# chose: AYNe4DN8doM with count 42 sum 42
# remaining_audios: 31 with extra videos 0 video sum 42
# chose: fnCgpj9eppQ with count 22 sum 64
# remaining_audios: 9 with extra videos 0 video sum 64
# chose: jDQBmZR2y5g with count 7 sum 71
# remaining_audios: 2 with extra videos 0 video sum 71
# chose: Nyi6qwEWBZ8 with count 1 sum 72
# remaining_audios: 1 with extra videos 0 video sum 72
# RETRY: 29
# remaining_audios: 73 with extra videos 0 video sum 0
# chose: faoz-h9t4zE with count 19 sum 19
# remaining_audios: 54 with extra videos 0 video sum 19
# ...
# RETRY: 26
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 25
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 24
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 23
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 22
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 21
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 20
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 19
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 18
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 17
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 16
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 15
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 14
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 13
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 12
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 11
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 10
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 9
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 8
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 7
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 6
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 5
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 4
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 3
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 2
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 1
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 0
# remaining_audios: 54 with extra videos 7 video sum 0
# RETRY: 30
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 29
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 28
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 27
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 26
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 25
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 24
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 23
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 22
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 21
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 20
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 19
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 18
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 17
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 16
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 15
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 14
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 13
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 12
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 11
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 10
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 9
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 8
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 7
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 6
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 5
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 4
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 3
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 2
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 1
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 0
# remaining_audios: 55 with extra videos 8 video sum 0
# RETRY: 30
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 29
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 28
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 27
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 26
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 25
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 24
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 23
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 22
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 21
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 20
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 19
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 18
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 17
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 16
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 15
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 14
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 13
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 12
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 11
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 10
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 9
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 8
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 7
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 6
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 5
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 4
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 3
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 2
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 1
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 0
# remaining_audios: 56 with extra videos 9 video sum 0
# RETRY: 30
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 29
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 28
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 27
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 26
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 25
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 24
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 23
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 22
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 21
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 20
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 19
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 18
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 17
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 16
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 15
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 14
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 13
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 12
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 11
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 10
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 9
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 8
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 7
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 6
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 5
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 4
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 3
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 2
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 1
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 0
# remaining_audios: 46 with extra videos -1 video sum 0
# RETRY: 30
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 29
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 28
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 27
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 26
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 25
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 24
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 23
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 22
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 21
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 20
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 19
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 18
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 17
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 16
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 15
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 14
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 13
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 12
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 11
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 10
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 9
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 8
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 7
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 6
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 5
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 4
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 3
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 2
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 1
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 0
# remaining_audios: 45 with extra videos -2 video sum 0
# RETRY: 30
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 29
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 28
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 27
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 26
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 25
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 24
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 23
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 22
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 21
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 20
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 19
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 18
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 17
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 16
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 15
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 14
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 13
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 12
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 11
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 10
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 9
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 8
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 7
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 6
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 5
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 4
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 3
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 2
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 1
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 0
# remaining_audios: 44 with extra videos -3 video sum 0
# RETRY: 30
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 29
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 28
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 27
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 26
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 25
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 24
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 23
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 22
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 21
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 20
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 19
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 18
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 17
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 16
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 15
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 14
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 13
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 12
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 11
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 10
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 9
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 8
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 7
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 6
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 5
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 4
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 3
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 2
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 1
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 0
# remaining_audios: 43 with extra videos -4 video sum 0
# RETRY: 30
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 29
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 28
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 27
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 26
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 25
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 24
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 23
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 22
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 21
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 20
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 19
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 18
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 17
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 16
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 15
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 14
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 13
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 12
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 11
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 10
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 9
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 8
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 7
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 6
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 5
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 4
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 3
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 2
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 1
# remaining_audios: 42 with extra videos -5 video sum 0
# RETRY: 0
# remaining_audios: 42 with extra videos -5 video sum 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 64
#      61         retries -= 1
#      63     if extra_audios_i >= len(extra_audios_list) or extra_audios / sample_size > 0.8:
# ---> 64         raise ValueError(speaker_id)
#      66 speaker_partition_df = speaker_df[speaker_df.video_id.isin(chosen_videos)].copy()
#      67 df = df[~df.index.isin(speaker_partition_df.index)]  # Remove chosen
#
# ValueError: id10105

# %%
df = state['dataset_metadata'].copy()
speaker_df = df[df.speaker_id == "id10105"].copy()
print(f"sample size {int(len(speaker_df) * v)}")
speaker_df.groupby(['video_id']).size().to_dict()
# Out:
# sample size 47
# {'ArZCDzx68s0': 12,
#  'F_LzPRjwV_0': 5,
#  'J1UdMqcSkgU': 9,
#  'LGTcAlSu2OA': 2,
#  'WXu5vaO0lQM': 3,
#  'Z4zvj6SOBZs': 8,
#  'jt5KpM6eAeA': 3,
#  'vJSc3FB4US0': 87,
#  'wrHyTrC37FQ': 184,
#  'yApWxyEm_Do': 3}

# %% [markdown]
# # Measure intra/inter video_id similarity

# %%
embeddings_dir = "/home/eernst/Voxceleb1/avg_embeddings/"

# %%
embeddings_paths = Path(embeddings_dir).rglob('*.pt')
embeddings = {}
for path in embeddings_paths:
    split_path = path.name.split("_")
    if "voxceleb1" in split_path:
        split_path.remove("voxceleb1")
    if "" in split_path:
        split_path.remove("")
    try:
        speaker_id, video_id, segment_id = split_path
    except:
        if len(split_path) == 4:
            speaker_id, video_id, segment_id = split_path[0], split_path[1] + split_path[2], split_path[3]
        
        elif len(split_path) == 5:
            speaker_id, video_id, segment_id = split_path[0], split_path[1] + split_path[2] + split_path[3], split_path[4]
        else:
            print(split_path)
            raise ValueError(path)
    segment_id = segment_id.replace(".pt", "")
    if speaker_id not in embeddings:
        embeddings[speaker_id] = {}
    if video_id not in embeddings[speaker_id]:
        embeddings[speaker_id][video_id] = {}
    with torch.no_grad():
        embeddings[speaker_id][video_id][segment_id] = torch.load(
            path,
            weights_only=True,
        )

# %%
len(embeddings)
# Out:
# 123

# %%
def cosine_distances_matrix(a, b, eps=1e-8):
    a_n, b_n = a.norm(dim=1)[:, None], b.norm(dim=1)[:, None]
    a_normalized = a / torch.clamp(a_n, min=eps)
    b_normalized = b / torch.clamp(b_n, min=eps)
    distances_matrix = 1 - torch.mm(a_normalized, b_normalized.transpose(0, 1))
    return distances_matrix

def mean_cosine_distance(vectors):
    distances_matrix = cosine_distances_matrix(vectors, vectors)
    different_distances = distances_matrix[torch.triu(distances_matrix, diagonal=1).nonzero(as_tuple=True)]
    return torch.mean(different_distances).item()

# %%
video_ids_to_remove = []
for speaker_id, video_id_dict in embeddings.items():
    for video_id, segment_id_dict in video_id_dict.items():
        video_id_embeddings = [embedding for embedding in segment_id_dict.values()]
        if len(video_id_embeddings) == 1:
            video_ids_to_remove.append((speaker_id, video_id))
for speaker_id, video_id in video_ids_to_remove:
    del embeddings[speaker_id][video_id]

# %%
len(video_ids_to_remove)
# Out:
# 2260

# %%
speaker_to_remove = []
for speaker_id, video_id_dict in embeddings.items():
    if not video_id_dict or len(video_id_dict) == 1:
        speaker_to_remove.append(speaker_id)
for speaker_id in speaker_to_remove:
    del embeddings[speaker_id]

# %%
len(speaker_to_remove)
# Out:
# 46

# %%
len(embeddings)
# Out:
# 77

# %%
video_ids = 0
for video_ids_dict in embeddings.values():
    video_ids += len(video_ids_dict)
print(f"There are {video_ids} videos")
# Out:
# There are 1046 videos

# %%
intra_video_id_distances = {}
for speaker_id, video_id_dict in embeddings.items():
    intra_video_id_distances[speaker_id] = {}
    for video_id, segment_id_dict in video_id_dict.items():
        video_id_embeddings = [embedding for embedding in segment_id_dict.values()]

        layers_distances = []
        for layer in range(13):
            layer_embeddings = [embedding[layer].unsqueeze(dim=0) for embedding in video_id_embeddings]
            layer_embeddings = torch.cat(layer_embeddings, dim=0)
            layer_distance = mean_cosine_distance(layer_embeddings)
            layers_distances.append(layer_distance)

            intra_video_id_distance = np.mean(np.array(layers_distances))
            intra_video_id_distances[speaker_id][video_id] = intra_video_id_distance

# %%
len(intra_video_id_distances)
# Out:
# 77

# %%
inter_video_id_distances = {}
for speaker_id, video_id_dict in embeddings.items():
    video_id_embeddings = []
    for video_id, segment_id_dict in video_id_dict.items():
        video_id_all_embeddings = [embedding.unsqueeze(dim=0) for embedding in segment_id_dict.values()]
        video_id_all_embeddings = torch.cat(video_id_all_embeddings, dim=0)
        video_id_mean_embedding = torch.mean(video_id_all_embeddings, dim=0)
        video_id_embeddings.append(video_id_mean_embedding)

    layers_distances = []
    for layer in range(13):
        layer_embeddings = [embedding[layer].unsqueeze(dim=0) for embedding in video_id_embeddings]
        layer_embeddings = torch.cat(layer_embeddings, dim=0)
        layer_distance = mean_cosine_distance(layer_embeddings)
        layers_distances.append(layer_distance)

    inter_video_id_distance = np.mean(np.array(layers_distances))
    inter_video_id_distances[speaker_id] = inter_video_id_distance

# %%
rows = []
for speaker_id in embeddings:
    inter_video_id_distance = inter_video_id_distances[speaker_id]
    for speaker_id, video_id_dict in embeddings.items():
        for video_id in video_id_dict:
            intra_video_id_distance = intra_video_id_distances[speaker_id][video_id]
            intra_v_inter_distance = abs(inter_video_id_distance - intra_video_id_distance)
            rows.append([speaker_id, video_id, inter_video_id_distance, intra_video_id_distance, intra_v_inter_distance])

# %%
df_distances = pd.DataFrame(rows, columns=["speaker_id", "video_id", "inter_video_id_distance", "intra_video_id_distance", "intra_v_inter_distance_diff"])
df_distances
# Out:
#       speaker_id     video_id  inter_video_id_distance  \
# 0        id10856    URycIznEI                 0.143094
# 1        id10856  lc1yDLHEKT8                 0.143094
# 2        id10856  qlkFLSNBKvI                 0.143094
# 3        id10856  cNvo7HjL8ys                 0.143094
# 4        id10856  1luQazgw6jo                 0.143094
# ...          ...          ...                      ...
# 80537    id11228  bM6TWdTWGKA                 0.164588
# 80538    id11228  DGNRvw7sNLM                 0.164588
# 80539    id11228  D851gSJLDak                 0.164588
# 80540    id11228  avOhqSI8AbU                 0.164588
# 80541    id11228  2ozfZytvgQI                 0.164588
#
#        intra_video_id_distance  intra_v_inter_distance_diff
# 0                     0.175446                     0.032351
# 1                     0.127802                     0.015292
# 2                     0.221063                     0.077969
# 3                     0.175990                     0.032896
# 4                     0.227188                     0.084093
# ...                        ...                          ...
# 80537                 0.112949                     0.051640
# 80538                 0.122627                     0.041962
# 80539                 0.135522                     0.029066
# 80540                 0.142493                     0.022095
# 80541                 0.141099                     0.023490
#
# [80542 rows x 5 columns]

# %%
df_distances.intra_v_inter_distance_diff.describe()
# Out:
# count    8.054200e+04
# mean     3.505817e-02
# std      2.853617e-02
# min      1.097528e-07
# 25%      1.377374e-02
# 50%      2.903220e-02
# 75%      4.945592e-02
# max      2.824960e-01
# Name: intra_v_inter_distance_diff, dtype: float64

# %%
df_distances.intra_video_id_distance.describe()
# Out:
# count    80542.000000
# mean         0.152814
# std          0.042056
# min          0.017197
# 25%          0.123909
# 50%          0.147991
# 75%          0.175996
# max          0.402956
# Name: intra_video_id_distance, dtype: float64

# %%
df_distances.inter_video_id_distance.describe()
# Out:
# count    80542.000000
# mean         0.152904
# std          0.016574
# min          0.120460
# 25%          0.139252
# 50%          0.152792
# 75%          0.165144
# max          0.186033
# Name: inter_video_id_distance, dtype: float64

# %%
len(intra_video_id_distances.values()) == video_ids # One by video_id
# Out:
# False

# %%
len(inter_video_id_distances) == len(embeddings) # One by speaker
# Out:
# True

# %%
len(inter_video_id_distances)
# Out:
# 77

# %%
mean_intra_video_id_distance
# Out:
# 0.15281383805212545

# %%
mean_inter_video_id_distance
# Out:
# 0.1529041120408477

# %%
print(f"inter-video distance is bigger than intra-video distance for a factor of {(mean_inter_video_id_distance / mean_intra_video_id_distance) - 1}")
# Out:
# inter-video distance is bigger than intra-video distance for a factor of 0.0005907448557862516
